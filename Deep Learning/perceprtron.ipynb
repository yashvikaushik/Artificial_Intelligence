# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_placement_data.csv")

# %%
df.head()
# Out:
#     IQ  CGPA  Skill_Level  Placed
# 0  117  7.89            8       1
# 1   92  7.04            6       0
# 2   89  6.19            4       0
# 3   85  9.52            9       0
# 4  144  7.87            9       1

# %%
df.shape
# Out:
# (100, 4)

# %%
X = df[['IQ', 'CGPA', 'Skill_Level']]
y = df['Placed']

# %%
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(
    X['IQ'], X['CGPA'], X['Skill_Level'],
    c=y, cmap='coolwarm', s=50
)

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-48.  ,   1.98,  95.  ]])

# %%
p.intercept_
# Out:
# array([-19.])

# %%
# Create grid
x_range = np.linspace(X['IQ'].min(), X['IQ'].max(), 30)
y_range = np.linspace(X['CGPA'].min(), X['CGPA'].max(), 30)
XX, YY = np.meshgrid(x_range, y_range)

# Decision plane equation
w = model.coef_[0]
b = model.intercept_[0]
ZZ = -(w[0]*XX + w[1]*YY + b) / w[2]

# 3D Plot
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

# Plot decision surface
ax.plot_surface(
    XX, YY, ZZ,
    alpha=0.25,
    color='green',
    rstride=1,
    cstride=1
)

# Plot points
ax.scatter(
    X['IQ'], X['CGPA'], X['Skill_Level'],
    c=y, cmap='coolwarm',
    s=60, edgecolors='k'
)

ax.set_xlabel("IQ")
ax.set_ylabel("CGPA")
ax.set_zlabel("Skill Level")
ax.set_title("3D Perceptron Decision Boundary")

plt.show()
