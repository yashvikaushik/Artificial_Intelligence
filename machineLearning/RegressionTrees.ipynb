# %%
import numpy as np 
import pandas as pd 
from sklearn.metrics import accuracy_score,classification_report,r2_score
from sklearn.tree import DecisionTreeRegressor 
from sklearn.datasets import  fetch_california_housing
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
data=fetch_california_housing()

# %%
X=data.data

# %%
y=data.target

# %%
df=pd.DataFrame(X,columns=data.feature_names)

# %%
df["price"]=y

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.3)

# %%
X_train
# Out:
# array([[   4.1312    ,   35.        ,    5.88235294, ...,    2.98529412,
#           33.93      , -118.02      ],
#        [   2.8631    ,   20.        ,    4.40120968, ...,    2.0141129 ,
#           32.79      , -117.09      ],
#        [   4.2026    ,   24.        ,    5.61754386, ...,    2.56491228,
#           34.59      , -120.14      ],
#        ...,
#        [   2.9344    ,   36.        ,    3.98671727, ...,    3.33206831,
#           34.03      , -118.38      ],
#        [   5.7192    ,   15.        ,    6.39534884, ...,    3.17889088,
#           37.58      , -121.96      ],
#        [   2.5755    ,   52.        ,    3.40257649, ...,    2.10869565,
#           37.77      , -122.42      ]])

# %%
model=DecisionTreeRegressor(criterion="squared_error",max_depth=9,min_samples_leaf=4,min_samples_split=10)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=9, min_samples_leaf=4, min_samples_split=10)

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([0.551645  , 0.79984878, 4.887041  , ..., 2.11580233, 1.46893426,
#        2.00780706])

# %%
df.shape
# Out:
# (20640, 9)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.6159461254888647

# %%
param = {
    'criterion':['squared_error','absolute_error'],
    'max_depth': [2,3,4,5,6,7,8,9,10],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,4]
}

# %%
tuning=GridSearchCV(estimator=DecisionTreeRegressor(),param_grid=param,cv=5,scoring="r2")

# %%
tuning.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='r2')

# %%
print(tuning.best_params_)
# Out:
# {'criterion': 'squared_error', 'max_depth': 9, 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
print(tuning.best_score_)
# Out:
# 0.6883353989717805
